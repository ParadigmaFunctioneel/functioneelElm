# %% [markdown]
# # Docentenscholing keuzethema Programmeerparadigma's
#
# ## Workshop 10 juni 2020 – Introductie en basis

# %% [markdown]
# Het hands-on gedeelte van deze workshop hebben we niet op de server gedaan, omdat die crashte.
# In plaats daarvan hebben we https://guide.elm-lang.org/core_language.html gebruikt, waar in de zwarte boxen een elm-interpreter draait.
#
# De oefeningen die we daar gedaan hebben staan ruwweg in het notebook hieronder. Commentaar staat meestal *na* het voorbeeld.

# %% [markdown]
# Dit is een Elm REPL notebook. Zie pijl.![Screenshot%202020-06-11%2016.48.40.png](attachment:Screenshot%202020-06-11%2016.48.40.png)

# %% [markdown]
# ### Values en expressions

# %%
2 + 2
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #ff90e8">4</span><span style="color: #404356"> : number</span>
#
# </pre>
# </body>
#
# </html>

# %% [markdown]
# Type regels elm in een cell, executeer met **Ctrl-Enter** of **Shift-Enter**.

# %%
"ape" ++ "brood"++"boom"
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi93 { color: #ea9540; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #ea9540">&quot;apebroodboom&quot;</span><span style="color: #404356"> : String</span>
#
# </pre>
# </body>
#
# </html>

# %% [markdown]
# Om operatoren hoeven geen spaties te staan, maar het is goede stijl om dat wel te doen.

# %% [markdown]
# ### Definties

# %%
x = 3
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #ff90e8">3</span><span style="color: #404356"> : number</span>
#
# </pre>
# </body>
#
# </html>

# %%
naam = "Coen"
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi93 { color: #ea9540; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #ea9540">&quot;Coen&quot;</span><span style="color: #404356"> : String</span>
#
# </pre>
# </body>
#
# </html>

# %% [markdown]
# In dit notebook wordt na de evaluatie van een cel het resultaat en het type van het resultaat gezet.

# %% [markdown]
# Er is geen onderscheid tussen variabelen (namen van waarden) en functies. Je definieert ze met =.

# %%
greet2 name = \
    "Dag, " ++ name ++ " " ++ name
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi36 { color: #00aaaa; }
# .ansi90 { color: #404356; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #00aaaa">&lt;function&gt;</span><span style="color: #404356"> : String -&gt; String</span>
#
# </pre>
# </body>
#
# </html>

# %% [markdown]
# Let op de \ achter iedere regel (behalve de laatste) in de cel. Dit is alleen nodig in deze Elm-REPL notebooks.

# %%
greet2 "Coen"
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi93 { color: #ea9540; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #ea9540">&quot;Dag, Coen Coen&quot;</span><span style="color: #404356"> : String</span>
#
# </pre>
# </body>
#
# </html>

# %%
cijfers = [7, 5, 8, 8, 4]
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# [<span style="color: #ff90e8">7</span>,<span style="color: #ff90e8">5</span>,<span style="color: #ff90e8">8</span>,<span style="color: #ff90e8">8</span>,<span style="color: #ff90e8">4</span>]<span style="color: #404356"> : List number</span>
#
# </pre>
# </body>
#
# </html>

# %%
List.length cijfers
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #ff90e8">5</span><span style="color: #404356"> : Int</span>
#
# </pre>
# </body>
#
# </html>

# %% [markdown]
# Functies zijn ingedeeld in packages. De naam van het package, zoals List, moeten vóór de functienaam staan. Je kunt packages importeren zodat dat niet nodig is, maar dat werkt niet in deze Elm-REPL notebooks.

# %% [markdown]
# ### Recursie

# %%
krikopFout cs = \
    case cs of \
    [] -> [] \
    c :: ds -> (c+1) :: krikop cs
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi36 { color: #00aaaa; }
# .ansi90 { color: #404356; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #00aaaa">&lt;function&gt;</span><span style="color: #404356"> : List number -&gt; List number</span>
#
# </pre>
# </body>
#
# </html>

# %%
krikopFout cijfers
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# [<span style="color: #ff90e8">8</span>,<span style="color: #ff90e8">8</span>,<span style="color: #ff90e8">6</span>,<span style="color: #ff90e8">9</span>,<span style="color: #ff90e8">9</span>,<span style="color: #ff90e8">5</span>]<span style="color: #404356">
#     : List number</span>
#
# </pre>
# </body>
#
# </html>

# %%
krikop cs = \
    case cs of \
    [] -> [] \
    c :: ds -> (c+1) :: krikop ds
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi36 { color: #00aaaa; }
# .ansi90 { color: #404356; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #00aaaa">&lt;function&gt;</span><span style="color: #404356"> : List number -&gt; List number</span>
#
# </pre>
# </body>
#
# </html>

# %%
krikop cijfers
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# [<span style="color: #ff90e8">8</span>,<span style="color: #ff90e8">6</span>,<span style="color: #ff90e8">9</span>,<span style="color: #ff90e8">9</span>,<span style="color: #ff90e8">5</span>]<span style="color: #404356"> : List number</span>
#
# </pre>
# </body>
#
# </html>

# %% [markdown]
# Definieer een functie die het verhogen van één cijfer wat subtieler doet.

# %%
increment n = \
    if n < 10 then n + 1 \
    else n
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi36 { color: #00aaaa; }
# .ansi90 { color: #404356; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #00aaaa">&lt;function&gt;</span><span style="color: #404356"> : number -&gt; number</span>
#
# </pre>
# </body>
#
# </html>

# %%
increment 5
increment 10
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# <span style="color: #ff90e8">6</span><span style="color: #404356"> : number</span>
# <span style="color: #ff90e8">10</span><span style="color: #404356"> : number</span>
#
# </pre>
# </body>
#
# </html>

# %% [markdown]
# De functie **map** uit List voert een functie uit op alle elementen van een lijst. Functie en lijst zijn beide parameters van de functie.

# %%
List.map increment cijfers
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# [<span style="color: #ff90e8">8</span>,<span style="color: #ff90e8">6</span>,<span style="color: #ff90e8">9</span>,<span style="color: #ff90e8">9</span>,<span style="color: #ff90e8">5</span>]<span style="color: #404356"> : List number</span>
#
# </pre>
# </body>
#
# </html>

# %%
List.map increment (List.map increment cijfers)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# [<span style="color: #ff90e8">9</span>,<span style="color: #ff90e8">7</span>,<span style="color: #ff90e8">10</span>,<span style="color: #ff90e8">10</span>,<span style="color: #ff90e8">6</span>]<span style="color: #404356"> : List number</span>
#
# </pre>
# </body>
#
# </html>

# %%
List.map increment cijfers |> List.map increment
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# [<span style="color: #ff90e8">9</span>,<span style="color: #ff90e8">7</span>,<span style="color: #ff90e8">10</span>,<span style="color: #ff90e8">10</span>,<span style="color: #ff90e8">6</span>]<span style="color: #404356"> : List number</span>
#
# </pre>
# </body>
#
# </html>

# %% [markdown]
# **|>** stuurt het resultaat van het linkerdeel als input naar het rechterdeel. Zoals een pipe, **|**, in de Unix shell. Scheelt haakjes en laat je de fucnties in de logsiche volgorde opschrijven.

# %% [markdown]
# [Niet in de workshop]. Je kunt de herhaling van de operatie ook in het functie-argument van List.map laten plaatsvinden. **>>** is functie-compositie. (rondje in de wiskunde, maar die werkt in de omgekeerde volgorde; wil je precies die, dan gebruik je **<<**)

# %%
List.map (increment >> increment) cijfers
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# [<span style="color: #ff90e8">9</span>,<span style="color: #ff90e8">7</span>,<span style="color: #ff90e8">10</span>,<span style="color: #ff90e8">10</span>,<span style="color: #ff90e8">6</span>]<span style="color: #404356"> : List number</span>
#
# </pre>
# </body>
#
# </html>

# %% [markdown]
# #### Twee concatenatie-operatoren
#
# **++**      schakelt twee lists of strings aan elkaar
#
# **::**      zet een *element* voor een lijst

# %%
[1] ++ [2,3]
1 :: [2,3]
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# [<span style="color: #ff90e8">1</span>,<span style="color: #ff90e8">2</span>,<span style="color: #ff90e8">3</span>]<span style="color: #404356"> : List number</span>
# [<span style="color: #ff90e8">1</span>,<span style="color: #ff90e8">2</span>,<span style="color: #ff90e8">3</span>]<span style="color: #404356"> : List number</span>
#
# </pre>
# </body>
#
# </html>

# %%
[1,2] ++ [3,4]
1 :: 2 :: [3,4]
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .body_foreground > .bold,.bold > .body_foreground, body.body_foreground > pre > .bold { color: #FFFFFF; font-weight: normal; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi90 { color: #404356; }
# .ansi95 { color: #ff90e8; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# [<span style="color: #ff90e8">1</span>,<span style="color: #ff90e8">2</span>,<span style="color: #ff90e8">3</span>,<span style="color: #ff90e8">4</span>]<span style="color: #404356"> : List number</span>
# [<span style="color: #ff90e8">1</span>,<span style="color: #ff90e8">2</span>,<span style="color: #ff90e8">3</span>,<span style="color: #ff90e8">4</span>]<span style="color: #404356"> : List number</span>
#
# </pre>
# </body>
#
# </html>
